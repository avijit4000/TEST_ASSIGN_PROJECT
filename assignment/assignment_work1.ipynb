# %% [markdown]
# <a href="https://colab.research.google.com/github/avijit4000/TEST_ASSIGN_PROJECT/blob/main/assignment/assignment_work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Q.1. Use the taxi trip dataset to find clusters of locations that might belong to a particular cluster
# having similar kinds of trip features. Use DBSCAN algo for this.
# ● Show the locations belonging to each cluster over a map.
# ● Perform the analysis of trips belonging to the same clusters and point out the
# distinguishing features and insights.
# ● Also, divide a day in 1-hour slot and show a time of day based analysis of each cluster
# Note: To map the ZoneId(Pickup and Dropoff) to their spatial coordinates, use the Zone Lookup
# table from the link below. This will be used to create visualization of clusters on the map

# %%
import pandas as pd

# %%
data=pd.read_parquet("/content/drive/MyDrive/semester 2/Data Mining/assignment/yellow_tripdata_2023-01 (2).parquet")

# %%
location=pd.read_csv("/content/drive/MyDrive/semester 2/Data Mining/assignment/ZoneLookup.csv")

# %%
data.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
data.tail()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 3066761           3.05         NaN               None           107
# 3066762           5.80         NaN               None           112
# 3066763           4.67         NaN               None           114
# 3066764           3.15         NaN               None           230
# 3066765           2.85         NaN               None           262
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
location.head()
# Out:
#    ZoneId     Latitude     Longitude
# 0       1  191376.7495  9.359968e+05
# 1       2  164018.7544  1.031086e+06
# 2       3  254265.4787  1.026453e+06
# 3       4  202959.7824  9.906340e+05
# 4       5  140681.3514  9.318714e+05

# %%
location.shape
# Out:
# (263, 3)
